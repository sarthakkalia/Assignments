# %% [markdown]
# # Pandas Advance Assignment Solution

# %% [markdown]
# Q1. List any five functions of the pandas library with execution.

# %%
import pandas as pd

# %%
pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.set_index("Name")
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
df.reset_index()
# Out:
#      index  PassengerId  Survived  Pclass  \
# 0        0            1         0       3
# 1        1            2         1       1
# 2        2            3         1       3
# 3        3            4         1       1
# 4        4            5         0       3
# ..     ...          ...       ...     ...
# 886    886          887         0       2
# 887    887          888         1       1
# 888    888          889         0       3
# 889    889          890         1       1
# 890    890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %% [markdown]
# Q2. Given a Pandas DataFrame df with columns 'A', 'B', and 'C', write a Python function to re-index the
# DataFrame with a new index that starts from 1 and increments by 2 for each row.

# %%
data={
    'A':[1,2,3,4],
    'B':[3,44,3,5],
    'C':[13,34,5,4]
}
df1=pd.DataFrame(data,index=[1,3,5,7])

# %%
df1
# Out:
#    A   B   C
# 1  1   3  13
# 3  2  44  34
# 5  3   3   5
# 7  4   5   4

# %% [markdown]
# Q3. You have a Pandas DataFrame df with a column named 'Values'. Write a Python function that
# iterates over the DataFrame and calculates the sum of the first three values in the 'Values' column. The
# function should print the sum to the console.

# %%
df2=pd.DataFrame({
    'value':[1,2,3,4,5,6]
})

# %%
def sum():
    sum=df2.head(3).sum()
    return (f"The sum of first three value is {sum}")

# %%
sum()
# Out:
# 'The sum of first three value is value    6\ndtype: int64'

# %% [markdown]
# Q4. Given a Pandas DataFrame df with a column 'Text', write a Python function to create a new column
# 'Word_Count' that contains the number of words in each row of the 'Text' column.

# %%
df=pd.DataFrame({
    'text':["Sarthak","Kumar","Kalia","PW Skills"]
})

# %%
df['Word_Count']=df['text'].apply(len)

# %%
df
# Out:
#         text  Word_Count
# 0    Sarthak           7
# 1      Kumar           5
# 2      Kalia           5
# 3  PW Skills           9

# %% [markdown]
# Q5. How are DataFrame.size() and DataFrame.shape() different?

# %% [markdown]
# DataFrame.size() returns the total number of elements (cells) in the DataFrame and DataFrame.shape() returns a tuple representing the dimensions of the DataFrame.

# %%
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
df.size
# Out:
# 6

# %%
df
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
df.shape
# Out:
# (3, 2)

# %%
df
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %% [markdown]
# Q6. Which function of pandas do we use to read an excel file?

# %%
pd.read_excel("file_name.xlsx")

# %% [markdown]
# Q7. You have a Pandas DataFrame df that contains a column named 'Email' that contains email
# addresses in the format 'username@domain.com'. Write a Python function that creates a new column
# 'Username' in df that contains only the username part of each email address.

# %%
df=pd.DataFrame({
    'Email':['sarthakkalia45@gmail.com','skalia@hotmail.com']
})

# %%
def create_new(df):
    df['Username']=df['Email'].apply(lambda x:x.split('@')[0])

# %%
create_new(df)

# %%
df
# Out:
#                       Email        Username
# 0  sarthakkalia45@gmail.com  sarthakkalia45
# 1        skalia@hotmail.com          skalia

# %% [markdown]
# Q8. You have a Pandas DataFrame df with columns 'A', 'B', and 'C'. Write a Python function that selects
# all rows where the value in column 'A' is greater than 5 and the value in column 'B' is less than 10. The
# function should return a new DataFrame that contains only the selected rows.

# %%
df=pd.DataFrame({
    'A':[3,8,6,2,9],
    'B':[5,2,9,3,1],
    'C':[1,7,4,5,2]
})

# %%
def select(df):
    select_raw=df[(df['A'] >5) & (df['B']<10)]
    return select_raw

# %%
select(df)
# Out:
#    A  B  C
# 1  8  2  7
# 2  6  9  4
# 4  9  1  2

# %% [markdown]
# Q9. Given a Pandas DataFrame df with a column 'Values', write a Python function to calculate the mean,
# median, and standard deviation of the values in the 'Values' column.

# %%
df=pd.DataFrame({
    'Values':[3,8,6,2,9]
})

# %%
df.describe()
# Out:
#         Values
# count  5.00000
# mean   5.60000
# std    3.04959
# min    2.00000
# 25%    3.00000
# 50%    6.00000
# 75%    8.00000
# max    9.00000

# %%
df.mean()
# Out:
# Values    5.6
# dtype: float64

# %%
df.std()
# Out:
# Values    3.04959
# dtype: float64

# %%
df.median()
# Out:
# Values    6.0
# dtype: float64

# %% [markdown]
# Q10. Given a Pandas DataFrame df with a column 'Sales' and a column 'Date', write a Python function to
# create a new column 'MovingAverage' that contains the moving average of the sales for the past 7 days
# for each row in the DataFrame. The moving average should be calculated using a window of size 7 and
# should include the current day.

# %%
df=pd.DataFrame({
    'Sales':[60,45,60,50,30,10,40,70],
    'Date':['2023-01-01','2023-01-02','2023-01-03','2023-01-04','2023-01-05','2023-01-06','2023-01-07','2023-01-08']
})

# %%
def calculate_moving_average(df):
    df['Date'] = pd.to_datetime(df['Date'])
    df = df.sort_values(by='Date')
    df['Sales'] = pd.to_numeric(df['Sales'], errors='coerce')
    df['MovingAverage'] = df['Sales'].rolling(window=7, min_periods=1).mean()
    return df

# %%
df_with_moving_avg = calculate_moving_average(df)
print(df_with_moving_avg)
# Out:
#    Sales       Date  MovingAverage
# 0     60 2023-01-01      60.000000
# 1     45 2023-01-02      52.500000
# 2     60 2023-01-03      55.000000
# 3     50 2023-01-04      53.750000
# 4     30 2023-01-05      49.000000
# 5     10 2023-01-06      42.500000
# 6     40 2023-01-07      42.142857
# 7     70 2023-01-08      43.571429

# %% [markdown]
# Q11. You have a Pandas DataFrame df with a column 'Date'. Write a Python function that creates a new
# column 'Weekday' in the DataFrame. The 'Weekday' column should contain the weekday name (e.g.
# Monday, Tuesday) corresponding to each date in the 'Date' column.

# %%
df=pd.DataFrame({
    "Date": ['2023-01-01',
'2023-01-02',
'2023-01-03',
'2023-01-04',
'2023-01-05']
})

# %%
def add_weekday_column(df):
    df['Date'] = pd.to_datetime(df['Date'])
    df['Weekday'] = df['Date'].dt.strftime('%A')
    return df

# %%
df_with_weekday = add_weekday_column(df)
print(df_with_weekday)
# Out:
#         Date    Weekday
# 0 2023-01-01     Sunday
# 1 2023-01-02     Monday
# 2 2023-01-03    Tuesday
# 3 2023-01-04  Wednesday
# 4 2023-01-05   Thursday

# %% [markdown]
# Q12. Given a Pandas DataFrame df with a column 'Date' that contains timestamps, write a Python
# function to select all rows where the date is between '2023-01-01' and '2023-01-31'.

# %%
from datetime import datetime

data = {'Date': ['2023-01-01', '2023-01-15', '2023-01-30', '2023-02-05', '2023-02-15']}
df = pd.DataFrame(data)

df['Date'] = pd.to_datetime(df['Date'])
def select_rows_in_date_range(df, start_date, end_date):
    selected_rows = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]
    return selected_rows

start_date = datetime(2023, 1, 1)
end_date = datetime(2023, 1, 31)
selected_df = select_rows_in_date_range(df, start_date, end_date)
print(selected_df)
# Out:
#         Date
# 0 2023-01-01
# 1 2023-01-15
# 2 2023-01-30

# %% [markdown]
# Q13. To use the basic functions of pandas, what is the first and foremost necessary library that needs to
# be imported?

# %% [markdown]
# To use the basic functions of pandas in Python, you need to import the pandas library itself.

# %%
import pandas as pd
